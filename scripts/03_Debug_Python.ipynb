# %% [markdown]
# # Run Python Vectorization
#
# This interactive notebook allows you to run **only** the Python vectorization pipeline.
#
# > **Note:** The underlying logic has been moved to `source/slavv/dev/interactive.py`.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

# Add project root to path
project_root = Path('..').resolve()
sys.path.insert(0, str(project_root))

from slavv.dev.interactive import run_python_interface

run_python_interface()

# %% [markdown]
# ## Next Steps
#
# Check the output directory for Python results (in `python_results/` folder).
#
# Then, open **`04_Comparison_Dashboard.ipynb`** to compare with MATLAB results.
