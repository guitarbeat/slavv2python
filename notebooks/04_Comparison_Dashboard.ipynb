# %% [markdown]
# # Compare Results
#
# This interactive notebook allows you to select completed **MATLAB** and **Python** runs and generate a comparison report.
#
# > **Note:** The underlying logic has been moved to `source/slavv/evaluation/interactive.py`.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

# Add project root to path
project_root = Path('..').resolve()
sys.path.insert(0, str(project_root))

try:
    from slavv.evaluation.interactive import run_dashboard_interface, show_comparison_plots
    run_dashboard_interface()
except ImportError as e:
    print(f"Failed to load dashboard interface: {e}")
    print("Please ensure visualization dependencies (e.g., matplotlib, ipywidgets) are installed.")

# %% [markdown]
# ---
# # Visualization
#
# After running the comparison above, execute the cell below to visualize the results.

# %%
# This will automatically load the most recent comparison report
show_comparison_plots()
